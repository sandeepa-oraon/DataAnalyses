# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepa-oraon/DataAnalyses/blob/main/Pandas/sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# #Sorting

# %% [markdown]
# Sort DataFrame by One Column Value

# %%
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 40],
        'Score': [85, 90, 95, 80]}
df = pd.DataFrame(data)

# %% [markdown]
# using sort_values()

# %%
#in ascending order
df.sort_values(by='Age')
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95
# 3    David   40     80

# %%
#in descending order(set ascending to 'False')
df.sort_values(by='Age', ascending=False)
# Out:
#       Name  Age  Score
# 3    David   40     80
# 2  Charlie   35     95
# 1      Bob   30     90
# 0    Alice   25     85

# %% [markdown]
# ##Sort DataFrame by Multiple Columns

# %%
df.sort_values(by=['Age', 'Score'])
# Out:
#       Name  Age  Score
# 0    Alice   25     85
# 1      Bob   30     90
# 2  Charlie   35     95
# 3    David   40     80

# %% [markdown]
# This will first sort by Age, and if there are ties (same age), it will then sort by Score.

# %% [markdown]
# ##Sort DataFrame with Missing Values

# %%
data_with_nan = {"Name": ["Alice", "Bob", "Charlie", "David"],"Age": [28, 22, None, 22]}
df_nan = pd.DataFrame(data_with_nan)

# %%
df_nan
# Out:
#       Name   Age
# 0    Alice  28.0
# 1      Bob  22.0
# 2  Charlie   NaN
# 3    David  22.0

# %%
df_nan.sort_values(by= 'Age', na_position='first')
# Out:
#       Name   Age
# 2  Charlie   NaN
# 1      Bob  22.0
# 3    David  22.0
# 0    Alice  28.0

# %% [markdown]
# #Choosing the Sorting Algorithm

# %%
data = {
    "Name": ["Alice", "Bob", "Charlie", "David", "Eve"],
    "Age": [28, 22, 25, 22, 28],
    "Score": [85, 90, 95, 80, 88]
}

# %%
df= pd.DataFrame(data)
df
# Out:
#       Name  Age  Score
# 0    Alice   28     85
# 1      Bob   22     90
# 2  Charlie   25     95
# 3    David   22     80
# 4      Eve   28     88

# %%
df.sort_values(by='Age', kind='mergeSort')
# Out:
#       Name  Age  Score
# 1      Bob   22     90
# 3    David   22     80
# 2  Charlie   25     95
# 0    Alice   28     85
# 4      Eve   28     88

# %%
df.sort_values(by='Age', kind='quickSort')
# Out:
#       Name  Age  Score
# 1      Bob   22     90
# 3    David   22     80
# 2  Charlie   25     95
# 0    Alice   28     85
# 4      Eve   28     88
