# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepa-oraon/DataAnalyses/blob/main/Pandas/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Pandas dataframe")
# Out:
# Pandas dataframe

# %%
import pandas as pd
import numpy as np

# %%
#creating a DataFrame from 2D List
data= [[1,'John', 21],[2,'Josh', 20],[3,'Saly', 22],[4, 'Ram', 21]]
df= pd.DataFrame(data, columns=['id','Name', 'Age'])
df.set_index('id', inplace= True)
df
# Out:
#     Name  Age
# id
# 1   John   21
# 2   Josh   20
# 3   Saly   22
# 4    Ram   21

# %% [markdown]
# create pandas dataframe from list

# %%
data= {'Category': ['Array', 'Stack', 'Queue','Linked List'],
       'Marks': [20, 30, 29, 43]}
df= pd.DataFrame(data)

# %%
df
# Out:
#       Category  Marks
# 0        Array     20
# 1        Stack     30
# 2        Queue     29
# 3  Linked List     43

# %%
Data= {'id': [1, 2, 3, 4, 5],
       'Name': ['Josh', 'Shyam', 'Radha', 'Soni', 'Ben'],
       'Age': [23, 19, 21, 20, 19],
       'Gender': ['M', 'M', 'F', 'F', 'M'],
       'Specialization': ['Java', 'C', 'Java', 'Python', 'CPP']}
df= pd.DataFrame(Data)

# %%
df.set_index('id')
# Out:
#      Name  Age Gender Specialization
# id
# 1    Josh   23      M           Java
# 2   Shyam   19      M              C
# 3   Radha   21      F           Java
# 4    Soni   20      F         Python
# 5     Ben   19      M            CPP

# %%
df
# Out:
#    id   Name  Age Gender Specialization
# 0   1   Josh   23      M           Java
# 1   2  Shyam   19      M              C
# 2   3  Radha   21      F           Java
# 3   4   Soni   20      F         Python
# 4   5    Ben   19      M            CPP

# %%
data1={
       'Category': ['Array', 'Stack', 'Queue','Linked List', 'Tree'],
       'Stu1': [20, 30, 29, 38, 34],
       'stu2': [32, 43, 40, 39, 40],
       'stu3': [31, 29, 39, 40, 39]}

# %%
df= pd.DataFrame(data1)
df.transpose()
# Out:
#               0      1      2            3     4
# Category  Array  Stack  Queue  Linked List  Tree
# Stu1         20     30     29           38    34
# stu2         32     43     40           39    40
# stu3         31     29     39           40    39

# %%
df
# Out:
#       Category  Stu1  stu2  stu3
# 0        Array    20    32    31
# 1        Stack    30    43    29
# 2        Queue    29    40    39
# 3  Linked List    38    39    40
# 4         Tree    34    40    39

# %%
data=[['Stu1', 28, 'Engineer'],
      ['Stu2', 25, 'Data Scientist'],
      ['Stu3', '32', 'Manager']]

# %%
columns= ['Name', 'Age', 'Occupation']
df= pd.DataFrame(data, columns=columns)
df['Age']= pd.to_numeric(df['Age'])

# %%
df
# Out:
#    Name  Age      Occupation
# 0  Stu1   28        Engineer
# 1  Stu2   25  Data Scientist
# 2  Stu3   32         Manager

# %%
data = [['Geek1', 28, 'Engineer'],
        ['Geek2', None, 'Data Scientist'],
        ['Geek3', 32, None]]
column= ['Name', 'Age', 'Occupation']
df= pd.DataFrame(data, columns=column)
df
# Out:
#     Name   Age      Occupation
# 0  Geek1  28.0        Engineer
# 1  Geek2   NaN  Data Scientist
# 2  Geek3  32.0            None

# %%
df= df.replace({None: np.nan})
df
# Out:
#     Name   Age      Occupation
# 0  Geek1  28.0        Engineer
# 1  Geek2   NaN  Data Scientist
# 2  Geek3  32.0             NaN

# %% [markdown]
# creating DataFrame from Multiple Series

# %%
author = ['Jitender', 'Purnima',
          'Arpit', 'Jyoti']
article = [210, 211, 114, 178]

aut_ser= pd.Series(author)
aut_art= pd.Series(article)

frame={'Author': aut_ser,
       'Article': aut_art }
df= pd.DataFrame(frame)

df
# Out:
#      Author  Article
# 0  Jitender      210
# 1   Purnima      211
# 2     Arpit      114
# 3     Jyoti      178

# %%
age= [21, 23, 21, 20]
df['Age']= pd.Series(age)
df
# Out:
#      Author  Article  Age
# 0  Jitender      210   21
# 1   Purnima      211   23
# 2     Arpit      114   21
# 3     Jyoti      178   20

# %% [markdown]
# #Convert list of nested dictionary into Pandas dataframe

# %%
countries = {
    "1": {"Country": "India",
          "Capital": "Delhi",
          "Population": "5,123,456,789"},
    "2": {"Country": "New Country 2",
          "Capital": "New Capital 2",
          "Population": "987,654,321"},
    "3": {"Country": "New Country 3",
          "Capital": "New Capital 3",
          "Population": "111,222,333"}
}

# %%
#from_dict() gives the more control over key(whether rows and columns)
df= pd.DataFrame.from_dict(countries)
df
# Out:
#                         1              2              3
# Country             India  New Country 2  New Country 3
# Capital             Delhi  New Capital 2  New Capital 3
# Population  5,123,456,789    987,654,321    111,222,333

# %%
df= pd.DataFrame.from_dict(countries, orient='index')
df
# Out:
#          Country        Capital     Population
# 1          India          Delhi  5,123,456,789
# 2  New Country 2  New Capital 2    987,654,321
# 3  New Country 3  New Capital 3    111,222,333

# %% [markdown]
# ##Nested Dictionary to Pandas DataFrame using Native Method

# %%
li = [{
        "Student": [{"Exam": 90, "Grade": "a"},
                    {"Exam": 99, "Grade": "b"},
                    {"Exam": 97, "Grade": "c"},
                    ],
        "Name": "Paras Jain"
        },
        {
        "Student": [{"Exam": 89, "Grade": "a"},
                    {"Exam": 80, "Grade": "b"}
                    ],
        "Name": "Chunky Pandey"
        }]

# %%
li
# Out:
# [{'Student': [{'Exam': 90, 'Grade': 'a'},
#    {'Exam': 99, 'Grade': 'b'},
#    {'Exam': 97, 'Grade': 'c'}],
#   'Name': 'Paras Jain'},
#  {'Student': [{'Exam': 89, 'Grade': 'a'}, {'Exam': 80, 'Grade': 'b'}],
#   'Name': 'Chunky Pandey'}]

# %%
rows= []

for data in li:
  rData= data['Student']
  name= data['Name']

  for row in rData:
    row['Name']= name
    rows.append(row)

df= pd.DataFrame(rows)
df
# Out:
#    Exam Grade           Name
# 0    90     a     Paras Jain
# 1    99     b     Paras Jain
# 2    97     c     Paras Jain
# 3    89     a  Chunky Pandey
# 4    80     b  Chunky Pandey

# %%
# using pivot_table
df = df.pivot_table(index='Name', columns=['Grade'],
					values=['Exam']).reset_index()
# Defining columns
df.columns = ['Name', 'Maths', 'Physics', 'Chemistry']

# print dataframe
print(df)
# Out:
#             Name  Maths  Physics  Chemistry
# 0  Chunky Pandey   89.0     80.0        NaN
# 1     Paras Jain   90.0     99.0       97.0

# %%
df = pd.DataFrame({'City':['New York', 'Parague', 'New Delhi', 'Venice', 'new Orleans'],
                    'Event':['Music', 'Poetry', 'Theatre', 'Comedy', 'Tech_Summit'],
                    'Cost':[10000, 5000, 15000, 2000, 12000]})

index_ = [pd.Period('02-2018'), pd.Period('04-2018'),
          pd.Period('06-2018'), pd.Period('10-2018'), pd.Period('12-2018')]

df.index= index_
df
# df.transpose()
# Out:
#                 City        Event   Cost
# 2018-02     New York        Music  10000
# 2018-04      Parague       Poetry   5000
# 2018-06    New Delhi      Theatre  15000
# 2018-10       Venice       Comedy   2000
# 2018-12  new Orleans  Tech_Summit  12000

# %%
df_updated= df.replace(to_replace= '[nN]ew', value= 'New_', regex=True)
df_updated
# Out:
#                  City        Event   Cost
# 2018-02     New_ York        Music  10000
# 2018-04       Parague       Poetry   5000
# 2018-06    New_ Delhi      Theatre  15000
# 2018-10        Venice       Comedy   2000
# 2018-12  New_ Orleans  Tech_Summit  12000

# %% [markdown]
# "'You are given a dataframe containing details about various events in different cities. The names of certain cities contain some additional details enclosed in a bracket. Search for such names and remove the additional details.'"

# %%
df = pd.DataFrame({'City':['New York (City)', 'Parague', 'New Delhi (Delhi)', 'Venice', 'new Orleans'],
                    'Event':['Music', 'Poetry', 'Theatre', 'Comedy', 'Tech_Summit'],
                    'Cost':[10000, 5000, 15000, 2000, 12000]})
df
# Out:
#                 City        Event   Cost
# 0    New York (City)        Music  10000
# 1            Parague       Poetry   5000
# 2  New Delhi (Delhi)      Theatre  15000
# 3             Venice       Comedy   2000
# 4        new Orleans  Tech_Summit  12000

# %%
index_ =[pd.Period('02-2018'), pd.Period('04-2018'),
          pd.Period('06-2018'), pd.Period('10-2018'), pd.Period('12-2018')]

# %%
df.index= index_
df
# Out:
#                       City        Event   Cost
# 2018-02    New York (City)        Music  10000
# 2018-04            Parague       Poetry   5000
# 2018-06  New Delhi (Delhi)      Theatre  15000
# 2018-10             Venice       Comedy   2000
# 2018-12        new Orleans  Tech_Summit  12000

# %%
# Importing re package for using regular expressions
import re

# %%
def clean_names(city_name):
  if re.search('\(.*', city_name):
    pos= re.search('\(.*', city_name).start()
    return city_name[:pos]
  else:
    return city_name

df['City'].apply(clean_names)

# df['City']= df['City'].apply(clean_names)
# Out:
# 2018-02      New York
# 2018-04        Parague
# 2018-06     New Delhi
# 2018-10         Venice
# 2018-12    new Orleans
# Freq: M, Name: City, dtype: object

# %%
df
# Out:
#                       City        Event   Cost
# 2018-02    New York (City)        Music  10000
# 2018-04            Parague       Poetry   5000
# 2018-06  New Delhi (Delhi)      Theatre  15000
# 2018-10             Venice       Comedy   2000
# 2018-12        new Orleans  Tech_Summit  12000
