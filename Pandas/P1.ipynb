# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepa-oraon/DataAnalyses/blob/main/Pandas/P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# practiced from
#
#  https://www.w3resource.com/python-exercises/pandas/index-dataframe.php

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #1.

# %%
data= {'X':[78,85,96,80,86],
       'Y':[84,94,89,83,86],
       'Z':[86,97,96,72,83]}

df= pd.DataFrame(data)
df
# Out:
#     X   Y   Z
# 0  78  84  86
# 1  85  94  97
# 2  96  89  96
# 3  80  83  72
# 4  86  86  83

# %% [markdown]
# #2.

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df= pd.DataFrame(exam_data)
df.index= labels
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes

# %%
df[['attempts', 'name', 'qualify', 'score']]
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no    NaN
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %% [markdown]
# #3.

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
             'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
             'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
             'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df= pd.DataFrame(exam_data, index=labels)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, a to j
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      10 non-null     object
#  1   score     8 non-null      float64
#  2   attempts  10 non-null     int64
#  3   qualify   10 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 400.0+ bytes

# %% [markdown]
# #4.

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
              'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
              'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
              'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
df= pd.DataFrame(exam_data, index=labels)
df= df[['attempts', 'name', 'qualify', 'score']]
df.head(3)
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5

# %%
df.iloc[:3]
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5

# %% [markdown]
# #5.

# %%
df[['name', 'score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# d      James    NaN
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# h      Laura    NaN
# i      Kevin    8.0
# j      Jonas   19.0

# %% [markdown]
# #6.

# %%
print('Select specific columns and rows:')
df.loc[['b', 'd', 'f', 'g'], ['score', 'qualify']]
# Out:
# Select specific columns and rows:
#    score qualify
# b    9.0      no
# d    NaN      no
# f   20.0     yes
# g   14.5     yes

# %%
#or
df.iloc[[1, 3, 5, 6], [1, 3]]
# Out:
#       name  score
# b     Dima    9.0
# d    James    NaN
# f  Michael   20.0
# g  Matthew   14.5

# %% [markdown]
# #7.

# %%
df[df['attempts']>2]
# Out:
#    attempts     name qualify  score
# b         3     Dima      no    9.0
# d         3    James      no    NaN
# f         3  Michael     yes   20.0

# %% [markdown]
# #8.

# %%
print('Number of Rows: ', len(df.axes[0]))
print('Number of Columns: ', len(df.axes[1]))
# Out:
# Number of Rows:  10
# Number of Columns:  4

# %% [markdown]
# #9.

# %%
df[df['score'].isnull()]
# Out:
#    attempts   name qualify  score
# d         3  James      no    NaN
# h         1  Laura      no    NaN

# %% [markdown]
# #10.

# %%
df[df['score'].between(15, 20)]
# Out:
#    attempts       name qualify  score
# c         2  Katherine     yes   16.5
# f         3    Michael     yes   20.0
# j         1      Jonas     yes   19.0

# %% [markdown]
# #11.

# %%
df[(df['attempts']< 2)& (df['score']> 15)]
# Out:
#    attempts   name qualify  score
# j         1  Jonas     yes   19.0

# %% [markdown]
# #12.

# %%
df.loc['d', 'score']= 11.5
df
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no   11.5
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %% [markdown]
# #13.

# %%
print('Sum of the examination attempts by the stidents:\n', sum(df['attempts']))
# Out:
# Sum of the examination attempts by the stidents:
#  19

# %% [markdown]
# #14.

# %%
print('Mean score for each different student in data frame:\n', df['score'].mean())
# Out:
# Mean score for each different student in data frame:
#  13.333333333333334

# %% [markdown]
# #15.

# %%
df
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no   11.5
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %%
print('Delete the new row and display the original  rows:\n')
df.loc['k']= [1, 'Suresh', 'yes', 15.5]
df
# Out:
# Delete the new row and display the original  rows:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no   11.5
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0
# k         1     Suresh     yes   15.5

# %%
df.drop('k')
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3      James      no   11.5
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0

# %% [markdown]
# #16. Sorting the DataFrame by Multiple Columns

# %%
df.sort_values(by=['name', 'score'], ascending=[False, True])
# Out:
#    attempts       name qualify  score
# k         1     Suresh     yes   15.5
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# c         2  Katherine     yes   16.5
# j         1      Jonas     yes   19.0
# d         3      James      no   11.5
# e         2      Emily      no    9.0
# b         3       Dima      no    9.0
# a         1  Anastasia     yes   12.5

# %% [markdown]
# #17. Replacing Column Values (qualify)

# %%
df.replace({'qualify': {'yes': True, 'no': False}})
# Out:
# <ipython-input-24-33647c29fbed>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({'qualify': {'yes': True, 'no': False}})
#    attempts       name  qualify  score
# a         1  Anastasia     True   12.5
# b         3       Dima    False    9.0
# c         2  Katherine     True   16.5
# d         3      James    False   11.5
# e         2      Emily    False    9.0
# f         3    Michael     True   20.0
# g         1    Matthew     True   14.5
# h         1      Laura    False    NaN
# i         2      Kevin    False    8.0
# j         1      Jonas     True   19.0
# k         1     Suresh     True   15.5

# %% [markdown]
# #18. Changing a Specific Name Value

# %%
df['name']= df['name'].replace('James', 'Suresh')
df
# Out:
#    attempts       name qualify  score
# a         1  Anastasia     yes   12.5
# b         3       Dima      no    9.0
# c         2  Katherine     yes   16.5
# d         3     Suresh      no   11.5
# e         2      Emily      no    9.0
# f         3    Michael     yes   20.0
# g         1    Matthew     yes   14.5
# h         1      Laura      no    NaN
# i         2      Kevin      no    8.0
# j         1      Jonas     yes   19.0
# k         1     Suresh     yes   15.5

# %% [markdown]
# #19. Deleting a Column from the DataFrame

# %%
df.pop('attempts')
df
# Out:
#         name qualify  score
# a  Anastasia     yes   12.5
# b       Dima      no    9.0
# c  Katherine     yes   16.5
# d     Suresh      no   11.5
# e      Emily      no    9.0
# f    Michael     yes   20.0
# g    Matthew     yes   14.5
# h      Laura      no    NaN
# i      Kevin      no    8.0
# j      Jonas     yes   19.0
# k     Suresh     yes   15.5

# %% [markdown]
# #20. Inserting a New Column

# %%
color = ['Red','Blue','Orange','Red','White','White','Blue','Green','Green','Red','purple']
df['color']= color
df
# Out:
#         name qualify  score   color
# a  Anastasia     yes   12.5     Red
# b       Dima      no    9.0    Blue
# c  Katherine     yes   16.5  Orange
# d     Suresh      no   11.5     Red
# e      Emily      no    9.0   White
# f    Michael     yes   20.0   White
# g    Matthew     yes   14.5    Blue
# h      Laura      no    NaN   Green
# i      Kevin      no    8.0   Green
# j      Jonas     yes   19.0     Red
# k     Suresh     yes   15.5  purple

# %% [markdown]
# #21. Iterating Over DataFrame Rows

# %%
exam_data = [{'name':'Anastasia', 'score':12.5}, {'name':'Dima','score':9}, {'name':'Katherine','score':16.5}]
dd= pd.DataFrame(exam_data)
dd
# Out:
#         name  score
# 0  Anastasia   12.5
# 1       Dima    9.0
# 2  Katherine   16.5

# %%
for index, r in dd.iterrows():
  print(r['name'], r['score'])
# Out:
# Anastasia 12.5
# Dima 9.0
# Katherine 16.5

# %% [markdown]
# #22. Getting List from Column Headers

# %%
print(df.columns)
# Out:
# Index(['name', 'qualify', 'score', 'color'], dtype='object')

# %%
print(df.columns.values)
# Out:
# ['name' 'qualify' 'score' 'color']

# %% [markdown]
# 23. Renaming DataFrame Columns

# %%
col_data= [[1, 4, 7], [2, 5, 8], [3, 6, 9]]
ds= pd.DataFrame(col_data)
columns= ['col1', 'col2', 'col3']
ds.columns= columns
ds
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
ds.columns=['column1', 'column2', 'column3']
ds.rename(columns={'col1': 'column1', 'col2': 'column2', 'col3': 'column3' })
ds
# Out:
#    column1  column2  column3
# 0        1        4        7
# 1        2        5        8
# 2        3        6        9

# %% [markdown]
# #24. Selecting Rows Based on Column Values

# %%
d = {'col1': [1, 4, 3, 4, 5], 'col2': [4, 5, 6, 7, 8], 'col3': [7, 8, 9, 0, 1]}
d = pd.DataFrame(d)
d
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
print('Rows for colum1 value == 4')
d.loc[d['col1'] == 4]
# Out:
# Rows for colum1 value == 4
#    col1  col2  col3
# 1     4     5     8
# 3     4     7     0

# %% [markdown]
# #25. Changing the Order of DataFrame Columns

# %%
d[['col3', 'col2', 'col1']]
# Out:
#    col3  col2  col1
# 0     7     4     1
# 1     8     5     4
# 2     9     6     3
# 3     0     7     4
# 4     1     8     5

# %%
d.loc[5]= [10, 11, 12]

# %%
d
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# 5    10    11    12

# %% [markdown]
# #27. Write DataFrame to CSV (Tab Separator)

# %%
d.to_csv('DF_to_CSV.csv', sep='\t', index= False)
n_d= pd.read_csv('DF_to_CSV.csv')
n_d
# Out:
#   col1\tcol2\tcol3
# 0          1\t4\t7
# 1          4\t5\t8
# 2          3\t6\t9
# 3          4\t7\t0
# 4          5\t8\t1
# 5       10\t11\t12

# %% [markdown]
# #28. City Wise Count

# %%
df1 = pd.DataFrame({'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'city': ['California', 'Los Angeles', 'California', 'California', 'California', 'Los Angeles', 'Los Angeles', 'Georgia', 'Georgia', 'Los Angeles']})

# %%
df1
# Out:
#         name         city
# 0  Anastasia   California
# 1       Dima  Los Angeles
# 2  Katherine   California
# 3      James   California
# 4      Emily   California
# 5    Michael  Los Angeles
# 6    Matthew  Los Angeles
# 7      Laura      Georgia
# 8      Kevin      Georgia
# 9      Jonas  Los Angeles

# %%
df1.groupby(['city']).size().reset_index(name= 'no. of people')
# Out:
#           city  no. of people
# 0   California              4
# 1      Georgia              2
# 2  Los Angeles              4

# %% [markdown]
# #29. Delete Rows by Column Value

# %%
d[d.col2!= 5]
# Out:
#    col1  col2  col3
# 0     1     4     7
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1
# 5    10    11    12

# %%
d[d.col2!= 11]
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %%
d[d.col1!= 5]
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 5    10    11    12

# %%
d[d.col1!= 4]
# Out:
#    col1  col2  col3
# 0     1     4     7
# 2     3     6     9
# 4     5     8     1
# 5    10    11    12

# %%
d= d[d.col2!= 11]
d
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     4     5     8
# 2     3     6     9
# 3     4     7     0
# 4     5     8     1

# %% [markdown]
# #30. Widen Output Display

# %% [markdown]
# #31. Select Row by Integer Index

# %%
d.iloc[3]
# Out:
# col1    4
# col2    7
# col3    0
# Name: 3, dtype: int64

# %%
d.iloc[[3]]
# Out:
#    col1  col2  col3
# 3     4     7     0

# %% [markdown]
# #32. Replace NaN with Zeros

# %%
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
df1= pd.DataFrame(exam_data)

# %%
df1
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    NaN         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    NaN         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %%
df1.fillna(0)
# Out:
#         name  score  attempts qualify
# 0  Anastasia   12.5         1     yes
# 1       Dima    9.0         3      no
# 2  Katherine   16.5         2     yes
# 3      James    0.0         3      no
# 4      Emily    9.0         2      no
# 5    Michael   20.0         3     yes
# 6    Matthew   14.5         1     yes
# 7      Laura    0.0         1      no
# 8      Kevin    8.0         2      no
# 9      Jonas   19.0         1     yes

# %% [markdown]
# #33. Convert Index to Column

# %%
df1.reset_index(level=0, inplace=True)

# %%
df1
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin    8.0         2      no
# 9      9      Jonas   19.0         1     yes

# %%
# df1.to_string(index= False)

# %% [markdown]
# #34. Set Value in Cell by Index

# %%
# deprecated in pandas new version
# df1.set_value(8, 'Kevin', 10.2)

# %%
df1.at[8, 'kevin']= 10.2

# %%
df1
# Out:
#    index       name  score  attempts qualify  kevin
# 0      0  Anastasia   12.5         1     yes    NaN
# 1      1       Dima    9.0         3      no    NaN
# 2      2  Katherine   16.5         2     yes    NaN
# 3      3      James    NaN         3      no    NaN
# 4      4      Emily    9.0         2      no    NaN
# 5      5    Michael   20.0         3     yes    NaN
# 6      6    Matthew   14.5         1     yes    NaN
# 7      7      Laura    NaN         1      no    NaN
# 8      8      Kevin    8.0         2      no   10.2
# 9      9      Jonas   19.0         1     yes    NaN

# %%
df1.loc[8, 'Kevin'] = 10.2
df1
# Out:
#    index       name  score  attempts qualify  kevin  Kevin
# 0      0  Anastasia   12.5         1     yes    NaN    NaN
# 1      1       Dima    9.0         3      no    NaN    NaN
# 2      2  Katherine   16.5         2     yes    NaN    NaN
# 3      3      James    NaN         3      no    NaN    NaN
# 4      4      Emily    9.0         2      no    NaN    NaN
# 5      5    Michael   20.0         3     yes    NaN    NaN
# 6      6    Matthew   14.5         1     yes    NaN    NaN
# 7      7      Laura    NaN         1      no    NaN    NaN
# 8      8      Kevin    8.0         2      no   10.2   10.2
# 9      9      Jonas   19.0         1     yes    NaN    NaN

# %%
df1.loc[8, 'score'] = 10.2
df1
# Out:
#    index       name  score  attempts qualify  kevin  Kevin
# 0      0  Anastasia   12.5         1     yes    NaN    NaN
# 1      1       Dima    9.0         3      no    NaN    NaN
# 2      2  Katherine   16.5         2     yes    NaN    NaN
# 3      3      James    NaN         3      no    NaN    NaN
# 4      4      Emily    9.0         2      no    NaN    NaN
# 5      5    Michael   20.0         3     yes    NaN    NaN
# 6      6    Matthew   14.5         1     yes    NaN    NaN
# 7      7      Laura    NaN         1      no    NaN    NaN
# 8      8      Kevin   10.2         2      no   10.2   10.2
# 9      9      Jonas   19.0         1     yes    NaN    NaN

# %%
df1.drop(columns='Kevin', inplace=True)
df1
# Out:
#    index       name  score  attempts qualify  kevin
# 0      0  Anastasia   12.5         1     yes    NaN
# 1      1       Dima    9.0         3      no    NaN
# 2      2  Katherine   16.5         2     yes    NaN
# 3      3      James    NaN         3      no    NaN
# 4      4      Emily    9.0         2      no    NaN
# 5      5    Michael   20.0         3     yes    NaN
# 6      6    Matthew   14.5         1     yes    NaN
# 7      7      Laura    NaN         1      no    NaN
# 8      8      Kevin   10.2         2      no   10.2
# 9      9      Jonas   19.0         1     yes    NaN

# %%
df1.drop(columns='kevin', inplace=True)
df1
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin   10.2         2      no
# 9      9      Jonas   19.0         1     yes

# %% [markdown]
# #35. Count NaN Values

# %%
df1.isnull().values.sum()
# Out:
# np.int64(2)

# %% [markdown]
# #36. Drop Rows from DataFrame

# %%
df1
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin   10.2         2      no
# 9      9      Jonas   19.0         1     yes

# %%
df1.drop([9])
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
# 8      8      Kevin   10.2         2      no

# %%
df2= df1.drop([8, 9])
df2
# Out:
#    index       name  score  attempts qualify
# 0      0  Anastasia   12.5         1     yes
# 1      1       Dima    9.0         3      no
# 2      2  Katherine   16.5         2     yes
# 3      3      James    NaN         3      no
# 4      4      Emily    9.0         2      no
# 5      5    Michael   20.0         3     yes
# 6      6    Matthew   14.5         1     yes
# 7      7      Laura    NaN         1      no
